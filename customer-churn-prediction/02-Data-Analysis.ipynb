# %% [markdown]
# # Customer churn analysis
#
# ## Exploratory data analysis (EDA)
#
# This demo is continuation of the telco pipeline after data load, clean and transformation. We will now try to explore data using snowpark and other python library. This task help us identify further transformations, importatn variable discovery and any feature engineering thats required later.
#
# ## Analysis
#
# **We will analyse the following:**
#
# 1. The target variable
# 2. Variable types (categorical and numerical)
# 3. Missing data
# 4. Numerical variables
#     - Discrete
#     - Continuous
#     - Distributions
#     - Transformations
#
# 5. Categorical variables
#     - Cardinality
#     - Rare Labels
#     - Special mappings
#
#
# <img src="arch.jpg"/>

# %%
from snowflake.snowpark.session import Session
from snowflake.snowpark import functions as F
from snowflake.snowpark.types import *

import pandas as pd

from sklearn import linear_model

import matplotlib.pyplot as plt

# %matplotlib inline
import datetime as dt
import numpy as np
import seaborn as sns

#Snowflake connection info
from config import snowflake_conn_prop


# lets import some tranformations functions
from snowflake.snowpark.functions import udf, col, lit, translate, is_null, iff

# %%
from snowflake.snowpark import version
print(version.VERSION)

session = Session.builder.configs(snowflake_conn_prop).create()
print(session.sql('select current_warehouse(), current_database(), current_schema()').collect())
# Out:
# (0, 7, 0)
# [Row(CURRENT_WAREHOUSE()='LAB_S_WH', CURRENT_DATABASE()='SNOWPARK_QUICKSTART', CURRENT_SCHEMA()='TELCO')]

# %%
# %%time

raw = session.table('TRAIN_DATASET').sample(n = 20000)
data = raw.toPandas()
# Out:
# CPU times: user 756 ms, sys: 55.6 ms, total: 812 ms
# Wall time: 2.98 s

# %%
# to display all the columns of the dataframe in the notebook
pd.pandas.set_option('display.max_columns', None)
data.head()
# Out:
#    CUSTOMERID  COUNT  GENDER  SENIORCITIZEN  PARTNER  DEPENDENTS  \
# 0  6827-0Vm61      1    Male          False     True        True
# 1  4902-16JzM      1    Male           True     True       False
# 2  6012-yQS0H      1    Male          False     True       False
# 3  9771-X5YJ0      1  Female          False     True        True
# 4  2198-M6HGg      1    Male          False    False       False
#
#    TENUREMONTHS PHONESERVICE     MULTIPLELINES INTERNETSERVICE  \
# 0            61           No  No phone service             DSL
# 1             7          Yes                No     Fiber optic
# 2             8          Yes                No              No
# 3            61          Yes               Yes     Fiber optic
# 4             1          Yes                No             DSL
#
#         ONLINESECURITY         ONLINEBACKUP     DEVICEPROTECTION  \
# 0                  Yes                   No                  Yes
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  Yes                  Yes                  Yes
# 4                   No                  Yes                   No
#
#            TECHSUPPORT          STREAMINGTV      STREAMINGMOVIES  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  Yes                  Yes                  Yes
# 4                   No                   No                   No
#
#          CONTRACT PAPERLESSBILLING              PAYMENTMETHOD  MONTHLYCHARGES  \
# 0  Month-to-month            false  Bank transfer (automatic)           33.60
# 1  Month-to-month             true               Mailed check           70.10
# 2        One year            false    Credit card (automatic)           19.90
# 3        Two year            false    Credit card (automatic)          115.10
# 4  Month-to-month             true           Electronic check           50.75
#
#    TOTALCHARGES  CHURNVALUE
# 0       2117.20         0.0
# 1        467.55         1.0
# 2        153.95         0.0
# 3       7008.15         0.0
# 4         50.75         1.0

# %%
print(data.shape)
# Out:
# (20000, 22)

# %% [markdown]
# ## Check Target Distribution
#
# Let's begin by exploring the target distribution.

# %%
# We'll print the target variable, target names, and frequency of each unique value:

(unique, counts) = np.unique(data['CHURNVALUE'], return_counts=True)

print('Unique values of target variable', unique)
print('Counts of target variable', counts)
# Out:
# Unique values of target variable [0. 1.]
# Counts of target variable [13477  6523]

# %%
sns.barplot(x=unique, y=counts)
plt.title('Target variable counts in dataset')
plt.show()

# %% [markdown]
# ## Step 1: Define explonatory variables and target variable

# %%
data.head()
# Out:
#    CUSTOMERID  COUNT  GENDER  SENIORCITIZEN  PARTNER  DEPENDENTS  \
# 0  6827-0Vm61      1    Male          False     True        True
# 1  4902-16JzM      1    Male           True     True       False
# 2  6012-yQS0H      1    Male          False     True       False
# 3  9771-X5YJ0      1  Female          False     True        True
# 4  2198-M6HGg      1    Male          False    False       False
#
#    TENUREMONTHS PHONESERVICE     MULTIPLELINES INTERNETSERVICE  \
# 0            61           No  No phone service             DSL
# 1             7          Yes                No     Fiber optic
# 2             8          Yes                No              No
# 3            61          Yes               Yes     Fiber optic
# 4             1          Yes                No             DSL
#
#         ONLINESECURITY         ONLINEBACKUP     DEVICEPROTECTION  \
# 0                  Yes                   No                  Yes
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  Yes                  Yes                  Yes
# 4                   No                  Yes                   No
#
#            TECHSUPPORT          STREAMINGTV      STREAMINGMOVIES  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  Yes                  Yes                  Yes
# 4                   No                   No                   No
#
#          CONTRACT PAPERLESSBILLING              PAYMENTMETHOD  MONTHLYCHARGES  \
# 0  Month-to-month            false  Bank transfer (automatic)           33.60
# 1  Month-to-month             true               Mailed check           70.10
# 2        One year            false    Credit card (automatic)           19.90
# 3        Two year            false    Credit card (automatic)          115.10
# 4  Month-to-month             true           Electronic check           50.75
#
#    TOTALCHARGES  CHURNVALUE
# 0       2117.20         0.0
# 1        467.55         1.0
# 2        153.95         0.0
# 3       7008.15         0.0
# 4         50.75         1.0

# %%
# let's identify the categorical variables
# we will capture those of type *object* and boolean
cat_vars = [var for var in data.columns if ((data[var].dtype == 'O') or (data[var].dtype=="bool"))]

# Remove misinterpreted objects like "CustomerID"
cat_vars.pop(0)

print(cat_vars)
# Out:
# ['GENDER', 'SENIORCITIZEN', 'PARTNER', 'DEPENDENTS', 'PHONESERVICE', 'MULTIPLELINES', 'INTERNETSERVICE', 'ONLINESECURITY', 'ONLINEBACKUP', 'DEVICEPROTECTION', 'TECHSUPPORT', 'STREAMINGTV', 'STREAMINGMOVIES', 'CONTRACT', 'PAPERLESSBILLING', 'PAYMENTMETHOD']

# %%
# now let's identify the numerical variables
num_vars = [var for var in data.columns if var not in cat_vars and var != 'CHURNVALUE' and 'CUSTOMERID' not in var]

# number of numerical variables
print(num_vars)
# Out:
# ['COUNT', 'TENUREMONTHS', 'MONTHLYCHARGES', 'TOTALCHARGES']

# %%
# lets plot histograms for all continuous variables
print(data[num_vars].head())
data[num_vars].hist(bins=30, figsize=(15,15))
plt.show()
# Out:
#    COUNT  TENUREMONTHS  MONTHLYCHARGES  TOTALCHARGES
# 0      1            61           33.60       2117.20
# 1      1             7           70.10        467.55
# 2      1             8           19.90        153.95
# 3      1            61          115.10       7008.15
# 4      1             1           50.75         50.75

# %% [markdown]
# # Missing values
#
# Let's go ahead and find out which variables of the dataset contain missing values.

# %%
# make a list of the variables that contain missing values
vars_with_na = [var for var in data.columns if data[var].isnull().sum() > 0]

# determine percentage of missing values (expressed as decimals)
# and display the result ordered by % of missin data

data[vars_with_na].isnull().mean().sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Numerical variables
#
# Let's go ahead and find out what numerical variables we have in the dataset

# %%
print('Number of numerical variables: ', len(num_vars))

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
num_df = data[num_vars]
scaler.fit(num_df,y=None)

# visualise the numerical variables
num_df.head()
# Before Transformation
# Out:
# Number of numerical variables:  4
#    COUNT  TENUREMONTHS  MONTHLYCHARGES  TOTALCHARGES
# 0      1            61           33.60       2117.20
# 1      1             7           70.10        467.55
# 2      1             8           19.90        153.95
# 3      1            61          115.10       7008.15
# 4      1             1           50.75         50.75

# %%
# lets plot histograms for all continuous variables after they are scaled
new_df = pd.DataFrame(scaler.transform(num_df),columns=data[num_vars].columns)

#new_df2 = pd.DataFrame(np.log(new_df),columns=data[num_vars].columns)
new_df.head()
new_df.hist(bins=50, figsize=(20,20))
plt.show()

# %% [markdown]
# ## Taking care of outliers

# %%
def drop_outliers(df,out_name):
    iqr = 1.5 * (np.percentile(df[out_name], 75) - np.percentile(df[out_name], 25))
    df.drop(df[df[out_name] > (iqr + np.percentile(df[out_name], 75))].index, inplace=True)
    df.drop(df[df[out_name] < (np.percentile(df[out_name], 25) - iqr)].index, inplace=True)
    

drop_outliers(data,'TENUREMONTHS')
drop_outliers(data,'MONTHLYCHARGES')
drop_outliers(data,'TOTALCHARGES')

# %%
sns.boxplot(x=data['MONTHLYCHARGES'])
plt.show()

# %% [markdown]
# # Categorical variables
#
# Let's go ahead and analyse the categorical variables present in the dataset.

# %%
print('Number of categorical variables: ', len(cat_vars))
# Out:
# Number of categorical variables:  16

# %%
# let's preview the categorical variables
data[cat_vars].head()
# Out:
#    GENDER  SENIORCITIZEN  PARTNER  DEPENDENTS PHONESERVICE     MULTIPLELINES  \
# 0    Male          False     True        True           No  No phone service
# 1    Male           True     True       False          Yes                No
# 2    Male          False     True       False          Yes                No
# 3  Female          False     True        True          Yes               Yes
# 4    Male          False    False       False          Yes                No
#
#   INTERNETSERVICE       ONLINESECURITY         ONLINEBACKUP  \
# 0             DSL                  Yes                   No
# 1     Fiber optic                   No                   No
# 2              No  No internet service  No internet service
# 3     Fiber optic                  Yes                  Yes
# 4             DSL                   No                  Yes
#
#       DEVICEPROTECTION          TECHSUPPORT          STREAMINGTV  \
# 0                  Yes                   No                   No
# 1                   No                   No                   No
# 2  No internet service  No internet service  No internet service
# 3                  Yes                  Yes                  Yes
# 4                   No                   No                   No
#
#        STREAMINGMOVIES        CONTRACT PAPERLESSBILLING  \
# 0                   No  Month-to-month            false
# 1                   No  Month-to-month             true
# 2  No internet service        One year            false
# 3                  Yes        Two year            false
# 4                   No  Month-to-month             true
#
#                PAYMENTMETHOD
# 0  Bank transfer (automatic)
# 1               Mailed check
# 2    Credit card (automatic)
# 3    Credit card (automatic)
# 4           Electronic check

# %% [markdown]
# ## Number of labels: cardinality
#
# Let's evaluate how many different categories are present in each of the variables.

# %%
# get the number of unique values (cardinality) for each categorical variable

data[cat_vars].nunique().sort_values(ascending=False).plot.bar(figsize=(12,5));

# %% [markdown]
# ## Rare labels:
#
# Let's go ahead and investigate now if there are labels that are present only in a small number of customers:

# %%
print(cat_vars)
def analyse_rare_labels(df, var, rare_perc):
    df = df.copy()

    # determine the % of observations per category
    tmp = df.groupby(var)['CHURNVALUE'].count() / len(df)

    # return categories that are rare
    return tmp[tmp < rare_perc]

# print categories that are present in less than
# 1 % of the observations

for var in cat_vars:
    print(analyse_rare_labels(data, var, 0.01))
    print()
# Out:
# ['GENDER', 'SENIORCITIZEN', 'PARTNER', 'DEPENDENTS', 'PHONESERVICE', 'MULTIPLELINES', 'INTERNETSERVICE', 'ONLINESECURITY', 'ONLINEBACKUP', 'DEVICEPROTECTION', 'TECHSUPPORT', 'STREAMINGTV', 'STREAMINGMOVIES', 'CONTRACT', 'PAPERLESSBILLING', 'PAYMENTMETHOD']
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)
#
# Series([], Name: CHURNVALUE, dtype: float64)

# %% [markdown]
# ### So all the cat variables are distributed well

# %%
data[cat_vars].shape, data[num_vars].shape, data['CHURNVALUE'].shape
# Out:
# ((19994, 16), (19994, 4), (19994,))

# %%
# final columns that we want in our training data set are cat, num and target variables
final_cols = cat_vars + num_vars + ['CHURNVALUE']
final_cols
# Out:
# ['GENDER',
#  'SENIORCITIZEN',
#  'PARTNER',
#  'DEPENDENTS',
#  'PHONESERVICE',
#  'MULTIPLELINES',
#  'INTERNETSERVICE',
#  'ONLINESECURITY',
#  'ONLINEBACKUP',
#  'DEVICEPROTECTION',
#  'TECHSUPPORT',
#  'STREAMINGTV',
#  'STREAMINGMOVIES',
#  'CONTRACT',
#  'PAPERLESSBILLING',
#  'PAYMENTMETHOD',
#  'COUNT',
#  'TENUREMONTHS',
#  'MONTHLYCHARGES',
#  'TOTALCHARGES',
#  'CHURNVALUE']

# %%
# %%time
snowpark_train_df = session.write_pandas(data[final_cols], 'TELCO_TRAIN_SET', auto_create_table=True)
# Out:
# CPU times: user 288 ms, sys: 27.2 ms, total: 315 ms
# Wall time: 7.46 s

# %%
snowpark_train_df.toPandas()
# Out:
#        GENDER  SENIORCITIZEN  PARTNER  DEPENDENTS PHONESERVICE  \
# 0        Male          False     True        True           No
# 1        Male           True     True       False          Yes
# 2        Male          False     True       False          Yes
# 3      Female          False     True        True          Yes
# 4        Male          False    False       False          Yes
# ...       ...            ...      ...         ...          ...
# 19989    Male           True    False       False          Yes
# 19990  Female          False     True        True          Yes
# 19991    Male           True     True       False          Yes
# 19992    Male           True     True       False          Yes
# 19993    Male          False     True       False           No
#
#           MULTIPLELINES INTERNETSERVICE       ONLINESECURITY  \
# 0      No phone service             DSL                  Yes
# 1                    No     Fiber optic                   No
# 2                    No              No  No internet service
# 3                   Yes     Fiber optic                  Yes
# 4                    No             DSL                   No
# ...                 ...             ...                  ...
# 19989                No             DSL                   No
# 19990               Yes     Fiber optic                  Yes
# 19991               Yes     Fiber optic                   No
# 19992               Yes     Fiber optic                   No
# 19993  No phone service             DSL                   No
#
#               ONLINEBACKUP     DEVICEPROTECTION          TECHSUPPORT  \
# 0                       No                  Yes                   No
# 1                       No                   No                   No
# 2      No internet service  No internet service  No internet service
# 3                      Yes                  Yes                  Yes
# 4                      Yes                   No                   No
# ...                    ...                  ...                  ...
# 19989                   No                  Yes                   No
# 19990                   No                   No                   No
# 19991                   No                  Yes                   No
# 19992                   No                   No                   No
# 19993                   No                   No                   No
#
#                STREAMINGTV      STREAMINGMOVIES        CONTRACT  \
# 0                       No                   No  Month-to-month
# 1                       No                   No  Month-to-month
# 2      No internet service  No internet service        One year
# 3                      Yes                  Yes        Two year
# 4                       No                   No  Month-to-month
# ...                    ...                  ...             ...
# 19989                   No                   No  Month-to-month
# 19990                  Yes                  Yes        Two year
# 19991                   No                   No  Month-to-month
# 19992                   No                   No  Month-to-month
# 19993                  Yes                  Yes  Month-to-month
#
#       PAPERLESSBILLING              PAYMENTMETHOD  COUNT  TENUREMONTHS  \
# 0                false  Bank transfer (automatic)      1            61
# 1                 true               Mailed check      1             7
# 2                false    Credit card (automatic)      1             8
# 3                false    Credit card (automatic)      1            61
# 4                 true           Electronic check      1             1
# ...                ...                        ...    ...           ...
# 19989             true               Mailed check      1             1
# 19990             true  Bank transfer (automatic)      1            62
# 19991             true    Credit card (automatic)      1            68
# 19992            false           Electronic check      1             1
# 19993             true           Electronic check      1            29
#
#        MONTHLYCHARGES  TOTALCHARGES  CHURNVALUE
# 0               33.60       2117.20         0.0
# 1               70.10        467.55         1.0
# 2               19.90        153.95         0.0
# 3              115.10       7008.15         0.0
# 4               50.75         50.75         1.0
# ...               ...           ...         ...
# 19989           50.15         50.15         1.0
# 19990          101.15       6638.35         0.0
# 19991           80.35       5589.30         0.0
# 19992           74.30         74.30         0.0
# 19993           45.90       1332.40         0.0
#
# [19994 rows x 21 columns]

# %% [markdown]
# # Off to training a model and deplyment

# %%
session.close()
